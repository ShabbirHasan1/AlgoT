# %%
import pyfolio as pf
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df_1min = pd.read_csv(r"D:\AlgoT\data\daily_returnspyfolio1.csv")
df_15min = pd.read_csv(r'D:\AlgoT\data\daily_returnspyfolio15.csv')

# Convert the date column to datetime format
df_1min['date'] = pd.to_datetime(df_1min['date'])
df_15min['date'] = pd.to_datetime(df_15min['date'])
# Out:
# d:\AlgoT\.venv\Lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
df_1min
# Out:
#             totalPL   balance  totalPLcumsum  pct_change        day
# date
# 2019-01-01      0.0  100000.0            0.0         NaN    Tuesday
# 2019-01-02      0.0  100000.0            0.0         0.0  Wednesday
# 2019-01-03      0.0  100000.0            0.0         0.0   Thursday
# 2019-01-04      0.0  100000.0            0.0         0.0     Friday
# 2019-01-07      0.0  100000.0            0.0         0.0     Monday
# ...             ...       ...            ...         ...        ...
# 2024-05-13      0.0  662770.0       562770.0         0.0     Monday
# 2024-05-14      0.0  662770.0       562770.0         0.0    Tuesday
# 2024-05-15      0.0  662770.0       562770.0         0.0  Wednesday
# 2024-05-16      0.0  662770.0       562770.0         0.0   Thursday
# 2024-05-17      0.0  662770.0       562770.0         0.0     Friday
#
# [1327 rows x 5 columns]

# %%
df_15min
# Out:
#             totalPL   balance  totalPLcumsum  pct_change        day
# date
# 2019-01-01      0.0  100000.0            0.0         NaN    Tuesday
# 2019-01-02      0.0  100000.0            0.0         0.0  Wednesday
# 2019-01-03      0.0  100000.0            0.0         0.0   Thursday
# 2019-01-04      0.0  100000.0            0.0         0.0     Friday
# 2019-01-07      0.0  100000.0            0.0         0.0     Monday
# ...             ...       ...            ...         ...        ...
# 2024-05-13      0.0  932112.5       832112.5         0.0     Monday
# 2024-05-14      0.0  932112.5       832112.5         0.0    Tuesday
# 2024-05-15      0.0  932112.5       832112.5         0.0  Wednesday
# 2024-05-16      0.0  932112.5       832112.5         0.0   Thursday
# 2024-05-17      0.0  932112.5       832112.5         0.0     Friday
#
# [1327 rows x 5 columns]

# %%
df_15min.set_index('date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35624\3855979176.py in ?()
# ----> 1 df_15min.set_index('date', inplace=True)
#       2 df_1min.set_index('date', inpalce=True )
#
# d:\AlgoT\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['date'] are in the columns"

# %%
df_1min.set_index('date', inplace=True )

# %%
df_1min.index = pd.to_datetime(df_1min.index).to_pydatetime()
df_15min.index = pd.to_datetime(df_15min.index).to_pydatetime()

# %%
# Ensuring that 'pct_change' column is in float format
df_15min['pct_change'] = df_15min['pct_change'].astype(float)
df_1min['pct_change'] = df_1min['pct_change'].astype(float)

# %%
pf.create_full_tear_sheet(returns=df_1min['pct_change'])
pf.create_full_tear_sheet(returns=df_15min['pct_change'])
# Out:
# d:\AlgoT\.venv\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '43.212%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-05-17</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>63</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>43.212%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>562.77%</td>
#     </tr>
#     <tr>
# ...
