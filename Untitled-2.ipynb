# %%
import pandas as pd
df=pd.read_csv(r"D:\AlgoT\brokrage\finalbalance.csv")

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
# Ensure the 'Datetime' column is parsed correctly and converted to UTC
df['Datetime'] = pd.to_datetime(df['Date'], utc=True)



df['day'] = df['Date'].dt.day_name()

# %%
df['day'] = pd.to_datetime(df['Datetime']).dt.day_name()

# %%
# create a new column for date 
df['date'] = pd.to_datetime(df['Date']).dt.date

# %%
initial = 100000

# %%
# group by date and sum the totalPL
daily_returns = df.groupby('date')['CumReturns'].sum().reset_index()

# %%
daily_returns.head(50)
# Out:
#           date  CumReturns
# 0   2019-01-01         0.0
# 1   2019-01-02         0.0
# 2   2019-01-03         0.0
# 3   2019-01-04         0.0
# 4   2019-01-07         0.0
# 5   2019-01-08         0.0
# 6   2019-01-09         0.0
# 7   2019-01-10         0.0
# 8   2019-01-11         0.0
# 9   2019-01-14         0.0
# 10  2019-01-15         0.0
# 11  2019-01-16         0.0
# 12  2019-01-17         0.0
# 13  2019-01-18         0.0
# 14  2019-01-21         0.0
# 15  2019-01-22         0.0
# 16  2019-01-23         0.0
# 17  2019-01-24         0.0
# 18  2019-01-25     -1062.5
# 19  2019-01-28       677.5
# 20  2019-01-29      1310.0
# 21  2019-01-30     -2355.0
# 22  2019-01-31     -2627.5
# 23  2019-02-01         0.0
# 24  2019-02-04         0.0
# 25  2019-02-05         0.0
# 26  2019-02-06         0.0
# 27  2019-02-07         0.0
# 28  2019-02-08         0.0
# 29  2019-02-11      1217.5
# 30  2019-02-12       722.5
# 31  2019-02-13      -312.5
# 32  2019-02-14      2220.0
# 33  2019-02-15       550.0
# 34  2019-02-18      2127.5
# 35  2019-02-19     -1082.5
# 36  2019-02-20       917.5
# 37  2019-02-21       667.5
# 38  2019-02-22       190.0
# 39  2019-02-25      1015.0
# 40  2019-02-26     -2470.0
# 41  2019-02-27      -687.5
# 42  2019-02-28     -1410.0
# 43  2019-03-01      1925.0
# 44  2019-03-05     -2607.5
# 45  2019-03-06      1687.5
# 46  2019-03-07      2335.0
# 47  2019-03-08       352.5
# 48  2019-03-11       647.5
# 49  2019-03-12       480.0

# %%
daily_returns['balance'] = initial + daily_returns['CumReturns'].cumsum()

# %%
daily_returns['totalPLcumsum'] = daily_returns['CumReturns'].cumsum()

# %%
#create pct_change column
daily_returns['pct_change'] = daily_returns['balance'].pct_change()

# %%
daily_returns
# Out:
#             date  CumReturns   balance  totalPLcumsum  pct_change
# 0     2019-01-01         0.0  100000.0            0.0         NaN
# 1     2019-01-02         0.0  100000.0            0.0    0.000000
# 2     2019-01-03         0.0  100000.0            0.0    0.000000
# 3     2019-01-04         0.0  100000.0            0.0    0.000000
# 4     2019-01-07         0.0  100000.0            0.0    0.000000
# ...          ...         ...       ...            ...         ...
# 1228  2023-12-22      1930.0  841345.0       741345.0    0.002299
# 1229  2023-12-26        65.0  841410.0       741410.0    0.000077
# 1230  2023-12-27     -1102.5  840307.5       740307.5   -0.001310
# 1231  2023-12-28      2322.5  842630.0       742630.0    0.002764
# 1232  2023-12-29      -640.0  841990.0       741990.0   -0.000760
#
# [1233 rows x 5 columns]

# %%
# Assuming daily_returns is your DataFrame
daily_returns['date'] = pd.to_datetime(daily_returns['date'])

# Now you can use the .dt accessor
daily_returns['date'] = daily_returns['date'].dt.to_pydatetime()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\AlgoT\myenv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File d:\AlgoT\myenv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\AlgoT\myenv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 2
#       1 # Assuming daily_returns is your DataFrame
# ----> 2 daily_returns['date'] = pd.to_datetime(daily_returns['date'])
#       4 # Now you can use the .dt accessor
#       5 daily_returns['date'] = daily_returns['date'].dt.to_pydatetime()
#
# File d:\AlgoT\myenv\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File d:\AlgoT\myenv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
daily_returns['day'] = daily_returns['date'].dt.day_name()

# %%
daily_returns['Date']=daily_returns['date']

# %%
daily_returns.set_index('date', inplace=True)

# %%
if not pd.api.types.is_datetime64_any_dtype(daily_returns.index):
    daily_returns.index = pd.to_datetime(daily_returns.index)

# Ensure that 'pct_change' column is in float format
daily_returns['pct_change'] = daily_returns['pct_change'].astype(float)

# %%
daily_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1233 entries, 0 to 1232
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1233 non-null   datetime64[ns]
#  1   CumReturns     1233 non-null   float64
#  2   balance        1233 non-null   float64
#  3   totalPLcumsum  1233 non-null   float64
#  4   pct_change     1232 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 48.3 KB

# %%
daily_returns.dtypes
# Out:
# date             datetime64[ns]
# CumReturns              float64
# balance                 float64
# totalPLcumsum           float64
# pct_change              float64
# dtype: object

# %%
daily_returns.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14',
#                ...
#                '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20',
#                '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27',
#                '2023-12-28', '2023-12-29'],
#               dtype='datetime64[ns]', name='Date', length=1233, freq=None)

# %%
import pyfolio as pf
pf.create_full_tear_sheet(returns=daily_returns['pct_change'], benchmark_rets=None)
# Out:
# d:\AlgoT\myenv\lib\site-packages\pyfolio\timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# d:\AlgoT\myenv\lib\site-packages\pyfolio\plotting.py:648: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for stat, value in perf_stats[column].iteritems():
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-12-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>58</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>54.6%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>742.0%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>11.8%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>3.75</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>4.82</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-11.3%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>2.28</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>6.99</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.3%</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 2
#       1 import pyfolio as pf
# ----> 2 pf.create_full_tear_sheet(returns=daily_returns['pct_change'], benchmark_rets=None)
#
# File d:\AlgoT\myenv\lib\site-packages\pyfolio\tears.py:212, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, bayesian, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, style_factor_panel, sectors, caps, shares_held, volumes, percentile, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     206     returns = txn.adjust_returns_for_slippage(returns, positions,
#     207                                               transactions, slippage)
#     209 positions = utils.check_intraday(estimate_intraday, returns,
#     210                                  positions, transactions)
# --> 212 create_returns_tear_sheet(
#     213     returns,
#     214     positions=positions,
#     215     transactions=transactions,
#     216     live_start_date=live_start_date,
#     217     cone_std=cone_std,
#     218     benchmark_rets=benchmark_rets,
#     219     bootstrap=bootstrap,
#     220     turnover_denom=turnover_denom,
#     221     header_rows=header_rows,
#     222     set_context=set_context)
#     224 create_interesting_times_tear_sheet(returns,
#     225                                     benchmark_rets=benchmark_rets,
#     226                                     set_context=set_context)
#     228 if positions is not None:
#
# File d:\AlgoT\myenv\lib\site-packages\pyfolio\plotting.py:52, in customize.<locals>.call_w_context(*args, **kwargs)
#      50 if set_context:
#      51     with plotting_context(), axes_style():
# ---> 52         return func(*args, **kwargs)
#      53 else:
#      54     return func(*args, **kwargs)
#
# File d:\AlgoT\myenv\lib\site-packages\pyfolio\tears.py:528, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     518     returns = utils.clip_returns_to_benchmark(returns, benchmark_rets)
#     520 plotting.show_perf_stats(returns, benchmark_rets,
#     521                          positions=positions,
#     522                          transactions=transactions,
#    (...)
#     525                          live_start_date=live_start_date,
#     526                          header_rows=header_rows)
# --> 528 plotting.show_worst_drawdown_periods(returns)
#     530 always_sections = 11
#     531 live_start_date_sections = 1 if (live_start_date is not None) else 0
#
# File d:\AlgoT\myenv\lib\site-packages\pyfolio\plotting.py:1653, in show_worst_drawdown_periods(returns, top)
#    1637 def show_worst_drawdown_periods(returns, top=5):
#    1638     """
#    1639     Prints information about the worst drawdown periods.
#    1640
#    (...)
#    1650         Amount of top drawdowns periods to plot (default 5).
#    1651     """
# -> 1653     drawdown_df = timeseries.gen_drawdown_table(returns, top=top)
#    1654     utils.print_table(
#    1655         drawdown_df.sort_values('Net drawdown in %', ascending=False),
#    1656         name='Worst drawdown periods',
#    1657         float_format='{0:.2f}'.format,
#    1658     )
#
# File d:\AlgoT\myenv\lib\site-packages\pyfolio\timeseries.py:1008, in gen_drawdown_table(returns, top)
#    1003     df_drawdowns.loc[i, 'Duration'] = len(pd.date_range(peak,
#    1004                                                         recovery,
#    1005                                                         freq='B'))
#    1006 df_drawdowns.loc[i, 'Peak date'] = (peak.to_pydatetime()
#    1007                                     .strftime('%Y-%m-%d'))
# -> 1008 df_drawdowns.loc[i, 'Valley date'] = (valley.to_pydatetime()
#    1009                                       .strftime('%Y-%m-%d'))
#    1010 if isinstance(recovery, float):
#    1011     df_drawdowns.loc[i, 'Recovery date'] = recovery
#
# AttributeError: 'numpy.int64' object has no attribute 'to_pydatetime'
